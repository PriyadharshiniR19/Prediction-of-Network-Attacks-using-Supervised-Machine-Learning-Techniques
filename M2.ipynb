# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WSN.csv')
df.head()
# Out:
#        id   Time   Is_CH   who_CH   Dist_To_CH   ADV_S   ADV_R   JOIN_S  \
# 0  101000     50       1   101000      0.00000       1       0        0
# 1  101001     50       0   101044     75.32345       0       4        1
# 2  101002     50       0   101010     46.95453       0       4        1
# 3  101003     50       0   101044     64.85231       0       4        1
# 4  101004     50       0   101010      4.83341       0       4        1
#
#     JOIN_R   SCH_S   SCH_R  Rank   DATA_S   DATA_R   Data_Sent_To_BS  \
# 0       25       1       0     0        0     1200                48
# 1        0       0       1     2       38        0                 0
# 2        0       0       1    19       41        0                 0
# 3        0       0       1    16       38        0                 0
# 4        0       0       1    25       41        0                 0
#
#     dist_CH_To_BS   send_code   Expaned_Energy Attack_type
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Attack_type']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df = df.drop_duplicates()

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Attack_type',data=df)
# Out:
# <Axes: xlabel='Attack_type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df[' who CH'],color='magenta')

plt.subplot(1,2,2)
plt.hist(df[' Time'],color='grey')
# Out:
# (array([103975.,  76962.,  60771.,  30923.,  23164.,  17747.,  14857.,
#          13008.,  12237.,  12144.]),
#  array([  50.,  405.,  760., 1115., 1470., 1825., 2180., 2535., 2890.,
#         3245., 3600.]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(18,4), color='cyan')
plt.show()

# %%
df[' send_code '].hist(figsize=(10,5),color='pink')
# Out:
# <Axes: >

# %%
sns.scatterplot(df['Attack_type'], color='blueviolet') # scatter, plot, triplot, stackplot
# Out:
# <Axes: ylabel='Attack_type'>

# %%
sns.violinplot(df['Rank'], color='coral') #Violin plots can reveal whether the data within a category is unimodal or multimodal.
# Out:
# <Axes: >

# %%
df['Attack_type'].plot(kind='density',color="darkgoldenrod")
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df[' ADV_R'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.scatterplot(df['Expaned_Energy'], color='coral') # residplot, scatterplot
# Out:
# <Axes: ylabel='Expaned Energy'>

# %%
fig, ax = plt.subplots(figsize=(20,15))           #display the correlation matrix of a dataset. 

sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Attack_type')
# Out:
# Attack type
# 3    90.77
# 2     3.80
# 0     2.75
# 4     1.81
# 1     0.86
# Name: count, dtype: float64
