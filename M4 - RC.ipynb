# %% [markdown]
# # RIDGE CLASSIFIER ALGORITHEM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('WSN.csv')
df.head()
# Out:
#        id   Time   Is_CH   who_CH   Dist_To_CH   ADV_S   ADV_R   JOIN_S  \
# 0  101000     50       1   101000      0.00000       1       0        0
# 1  101001     50       0   101044     75.32345       0       4        1
# 2  101002     50       0   101010     46.95453       0       4        1
# 3  101003     50       0   101044     64.85231       0       4        1
# 4  101004     50       0   101010      4.83341       0       4        1
#
#     JOIN_R   SCH_S   SCH_R  Rank   DATA_S   DATA_R   Data_Sent_To_BS  \
# 0       25       1       0     0        0     1200                48
# 1        0       0       1     2       38        0                 0
# 2        0       0       1    19       41        0                 0
# 3        0       0       1    16       38        0                 0
# 4        0       0       1    25       41        0                 0
#
#     dist_CH_To_BS   send_code   Expaned_Energy Attack_type
# 0       130.08535            0         2.46940      Normal
# 1         0.00000            4         0.06957      Normal
# 2         0.00000            3         0.06898      Normal
# 3         0.00000            4         0.06673      Normal
# 4         0.00000            3         0.06534      Normal

# %%
df=df.dropna()

# %%
df.columns
# Out:
# Index([' id', ' Time', ' Is_CH', ' who_CH', ' Dist_To_CH', ' ADV_S', ' ADV_R',
#        ' JOIN_S', ' JOIN_R', ' SCH_S', ' SCH_R', 'Rank', ' DATA_S', ' DATA_R',
#        ' Data_Sent_To_BS', ' dist_CH_To_BS', ' send_code ', 'Expaned_Energy',
#        'Attack_type'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Attack_type']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df = df.drop_duplicates()

# %%
x1 = df.drop(labels='Attack_type', axis=1)
y1 = df.loc[:,'Attack_type']

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros =RandomOverSampler(random_state=42)
x,y=ros.fit_resample(x1,y1)
print("OUR DATASET COUNT         : ", Counter(y1))
print("OVER SAMPLING DATA COUNT  : ", Counter(y))
# Out:
# OUR DATASET COUNT         :  Counter({3: 332040, 2: 13909, 0: 10049, 4: 6633, 1: 3157})
# OVER SAMPLING DATA COUNT  :  Counter({3: 332040, 1: 332040, 4: 332040, 2: 332040, 0: 332040})

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42, stratify=y)
print("NUMBER OF TRAIN DATASET    : ", len(x_train))
print("NUMBER OF TEST DATASET      : ", len(x_test))
print("TOTAL NUMBER OF DATASET    : ", len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET    :  1328160
# NUMBER OF TEST DATASET      :  332040
# TOTAL NUMBER OF DATASET    :  1660200

# %%
print("NUMBER OF TRAIN DATASET    : ", len(y_train))
print("NUMBER OF TEST DATASET      : ", len(y_test))
print("TOTAL NUMBER OF DATASET    : ", len(y_train)+len(y_test))
# Out:
# NUMBER OF TRAIN DATASET    :  1328160
# NUMBER OF TEST DATASET      :  332040
# TOTAL NUMBER OF DATASET    :  1660200

# %%
from sklearn.linear_model import RidgeClassifier

# %%
RC = RidgeClassifier()
RC.fit(x_train,y_train)
# Out:
# RidgeClassifier()

# %%
predicted = RC.predict(x_test)

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,predicted)
print('THE CLASSIFICATION REPORT OF BERNOULLINB:\n\n',cr)
# Out:
# THE CLASSIFICATION REPORT OF BERNOULLINB:
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.95      0.80     66408
#            1       0.99      0.99      0.99     66408
#            2       0.95      0.54      0.69     66408
#            3       0.94      0.97      0.96     66408
#            4       0.89      0.91      0.90     66408
#
#     accuracy                           0.87    332040
#    macro avg       0.89      0.87      0.87    332040
# weighted avg       0.89      0.87      0.87    332040

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
print('THE CONFUSION MATRIX SCORE OF BERNOULLINB:\n\n\n',cm)
# Out:
# THE CONFUSION MATRIX SCORE OF BERNOULLINB:
#
#
#  [[63141     4     0     0  3263]
#  [  399 65604   158     0   247]
#  [26367   371 35999     0  3671]
#  [  146   247   895 64619   501]
#  [  603    83   830  4196 60696]]

# %%
from sklearn.model_selection import cross_val_score
accuracy = cross_val_score(RC, x, y, scoring='accuracy')
print('THE CROSS VALIDATION TEST RESULT OF ACCURACY :\n\n\n', accuracy*100)
# Out:
# THE CROSS VALIDATION TEST RESULT OF ACCURACY :
#
#
#  [87.10787857 87.43193591 87.53011685 87.22232261 87.2684014 ]

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(y_test,predicted)
print("THE ACCURACY SCORE OF RIDGE CLASSIFICAITON IS :",a*100)
# Out:
# THE ACCURACY SCORE OF RIDGE CLASSIFICAITON IS : 87.3566437778581

# %%
from sklearn.metrics import hamming_loss
hl = hamming_loss(y_test,predicted)
print("THE HAMMING LOSS OF RIDGE CLASSIFICAITON IS :",hl*100)
# Out:
# THE HAMMING LOSS OF RIDGE CLASSIFICAITON IS : 12.643356222141911

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, predicted, labels=RC.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=RC.classes_)
disp.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()
